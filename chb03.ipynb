# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /anaconda3
# python27              *  /anaconda3/envs/python27

# %%
from edf2csv import EDF
# Out:
# # conda environments:
# #
# base                     /anaconda3
# python27              *  /anaconda3/envs/python27

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_01.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_02.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_03.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_04.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_05.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_06.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_07.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_08.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_09.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_10.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_11.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_12.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_13.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_14.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_15.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_16.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_17.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_18.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_19.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_20.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (923136, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_21.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_22.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_23.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_24.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_25.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_26.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_27.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_28.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_29.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_30.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_31.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_32.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_33.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_34.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_35.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_36.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_37.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]

# %%
subject = '/Volumes/Transcend/chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_38.edf'

edf = EDF(subject)

signal = edf.signal()
info = edf.info()

print signal.shape
print info

edf.ann_to_csv()
edf.signal_to_csv()
# Out:
# (921600, 23)
# [256.0, ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8'], []]
